# %%
import numpy as np
import pandas as pd

# Read the CSV file
data = pd.read_csv("/Thyroid_Diff.csv")

# Display the first few rows of the data
data.head()
# Out:
#    Age Gender Smoking Hx Smoking Hx Radiothreapy Thyroid Function  \
# 0   27      F      No         No              No        Euthyroid
# 1   34      F      No        Yes              No        Euthyroid
# 2   30      F      No         No              No        Euthyroid
# 3   62      F      No         No              No        Euthyroid
# 4   62      F      No         No              No        Euthyroid
#
#           Physical Examination Adenopathy       Pathology     Focality Risk  \
# 0   Single nodular goiter-left         No  Micropapillary    Uni-Focal  Low
# 1          Multinodular goiter         No  Micropapillary    Uni-Focal  Low
# 2  Single nodular goiter-right         No  Micropapillary    Uni-Focal  Low
# 3  Single nodular goiter-right         No  Micropapillary    Uni-Focal  Low
# 4          Multinodular goiter         No  Micropapillary  Multi-Focal  Low
#
#      T   N   M Stage       Response Recurred
# 0  T1a  N0  M0     I  Indeterminate       No
# ...

# %%
# prompt: import warning

import warnings
warnings.filterwarnings("ignore")

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_1.groupby('Hx Smoking').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_0['Age'].plot(kind='hist', bins=20, title='Age')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Age

from matplotlib import pyplot as plt
data['Age'].plot(kind='hist', bins=20, title='Age')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
data.describe()
# Out:
#               Age
# count  383.000000
# mean    40.866841
# std     15.134494
# min     15.000000
# 25%     29.000000
# 50%     37.000000
# 75%     51.000000
# max     82.000000

# %%
from matplotlib import pyplot as plt
_df_18['Age'].plot(kind='line', figsize=(8, 4), title='Age')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# Rename the columns for better understanding
data.rename(columns={'Hx Smoking': 'Smoking History',
                   'Hx Radiothreapy': 'Radiotherapy History',
                   'Pathology': 'Types of Thyroid Cancer (Pathology)',
                   'T': 'Tumor',
                   'N': 'Lymph Nodes',
                   'M': 'Cancer Metastasis',
                  'Response' : 'Treatment Response'}, inplace=True)

# %%
data.head()
# Out:
#    Age Gender Smoking Smoking History Radiotherapy History Thyroid Function  \
# 0   27      F      No              No                   No        Euthyroid
# 1   34      F      No             Yes                   No        Euthyroid
# 2   30      F      No              No                   No        Euthyroid
# 3   62      F      No              No                   No        Euthyroid
# 4   62      F      No              No                   No        Euthyroid
#
#           Physical Examination Adenopathy Types of Thyroid Cancer (Pathology)  \
# 0   Single nodular goiter-left         No                      Micropapillary
# 1          Multinodular goiter         No                      Micropapillary
# 2  Single nodular goiter-right         No                      Micropapillary
# 3  Single nodular goiter-right         No                      Micropapillary
# 4          Multinodular goiter         No                      Micropapillary
#
# ...

# %%
#Replace The values with a more understandable values
data['Adenopathy'].replace({'No' : 'No Lympth Adenopathy' ,
                          'Left' : 'Left Side Body Adenopathy' ,
                          'Right' : 'Right Side Body Adenopathy' ,
                          'Extensive' : 'Extensive and Widespread'}, inplace = True)

data['Stage'].replace({'I' : 'First-Stage' , 'II' : 'Second-Stage' , 'III' : 'Third-Stage'} ,inplace = True)

data['Tumor'].replace({'T1a' : 'tumor that is 1 cm or smaller' , 'T1b' : 'tumor larger than 1 cm but not larger than 2 cm' ,
                     'T2' : 'tumor larger than 2 cm but not larger than 4 cm' ,
                     'T3a' : 'tumor larger than 4 cm' ,'T3b' : 'tumor that has grown outside the thyroid' ,
                     'T4a' : 'tumor that has invaded nearby structures' ,
                     'T4b' : 'tumor that has invaded nearby structures'} , inplace =True)

data['Lymph Nodes'].replace({'N0' : 'no evidence of regional lymph node metastasis' ,
                     'N1b' : 'regional lymph node metastasis in the central  of the neck' ,
                     'N1a' : 'regional lymph node metastasis in the lateral of the neck'} , inplace =True)

data['Cancer Metastasis'].replace({'M0': 'no evidence of distant metastasis' , 'M1' : 'the presence of distant metastasis'} ,inplace =True )

# %%
data.head()
# Out:
#    Age Gender Smoking Smoking History Radiotherapy History Thyroid Function  \
# 0   27      F      No              No                   No        Euthyroid
# 1   34      F      No             Yes                   No        Euthyroid
# 2   30      F      No              No                   No        Euthyroid
# 3   62      F      No              No                   No        Euthyroid
# 4   62      F      No              No                   No        Euthyroid
#
#           Physical Examination            Adenopathy  \
# 0   Single nodular goiter-left  No Lympth Adenopathy
# 1          Multinodular goiter  No Lympth Adenopathy
# 2  Single nodular goiter-right  No Lympth Adenopathy
# 3  Single nodular goiter-right  No Lympth Adenopathy
# 4          Multinodular goiter  No Lympth Adenopathy
#
#   Types of Thyroid Cancer (Pathology)     Focality Risk  \
# 0                      Micropapillary    Uni-Focal  Low
# 1                      Micropapillary    Uni-Focal  Low
# ...

# %%
# Create a box plot to show the outliers and explore the data

import matplotlib.pyplot as plt
import seaborn as sns
# Create a 1x2 grid for the plots
fig, axes = plt.subplots(1, 2, figsize=(20, 5))

# Boxplot for Tumor
sns.boxplot(x='Tumor', y='Age', data=data, palette="OrRd", ax=axes[0])
axes[0].set_title('Boxplot of Age by Tumor Stage')
axes[0].set_xlabel('Tumor Stage')
axes[0].set_ylabel('Age')
axes[0].tick_params(axis='x', rotation=45)

# Boxplot for Stage
sns.boxplot(x='Stage', y='Age', data=data,palette="OrRd", ax=axes[1])
axes[1].set_title('Boxplot of Age by Cancer Stage')
axes[1].set_xlabel('Cancer Stage')
axes[1].set_ylabel('Age')
axes[1].tick_params(axis='x', rotation=0)

plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 383 entries, 0 to 382
# Data columns (total 17 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Age                                  383 non-null    int64
#  1   Gender                               383 non-null    object
#  2   Smoking                              383 non-null    object
#  3   Smoking History                      383 non-null    object
#  4   Radiotherapy History                 383 non-null    object
#  5   Thyroid Function                     383 non-null    object
#  6   Physical Examination                 383 non-null    object
#  7   Adenopathy                           383 non-null    object
#  8   Types of Thyroid Cancer (Pathology)  383 non-null    object
#  9   Focality                             383 non-null    object
#  10  Risk                                 383 non-null    object
# ...

# %%
def map_risk_to_percentage(risk):
    if risk == 'Low':
        return 1
    elif risk == 'Intermediate':
        return 2
    else:
        return 3

# Apply the function to create the new column
data['Risk Rate (Out of 3)'] = data['Risk'].apply(map_risk_to_percentage)

# %%
data.head()
# Out:
#    Age Gender Smoking Smoking History Radiotherapy History Thyroid Function  \
# 0   27      F      No              No                   No        Euthyroid
# 1   34      F      No             Yes                   No        Euthyroid
# 2   30      F      No              No                   No        Euthyroid
# 3   62      F      No              No                   No        Euthyroid
# 4   62      F      No              No                   No        Euthyroid
#
#           Physical Examination            Adenopathy  \
# 0   Single nodular goiter-left  No Lympth Adenopathy
# 1          Multinodular goiter  No Lympth Adenopathy
# 2  Single nodular goiter-right  No Lympth Adenopathy
# 3  Single nodular goiter-right  No Lympth Adenopathy
# 4          Multinodular goiter  No Lympth Adenopathy
#
#   Types of Thyroid Cancer (Pathology)     Focality Risk  \
# 0                      Micropapillary    Uni-Focal  Low
# 1                      Micropapillary    Uni-Focal  Low
# ...

# %%
# prompt: Using dataframe data: unique values for adenopathy , cancer metastasis, stage , types of thyroid cancer column

print("Unique values for Adenopathy:")
print(data['Adenopathy'].unique())
print("\nUnique values for Cancer Metastasis:")
print(data['Cancer Metastasis'].unique())
print("\nUnique values for Stage:")
print(data['Stage'].unique())
print("\nUnique values for Types of Thyroid Cancer:")
print(data['Types of Thyroid Cancer (Pathology)'].unique())
# Out:
# Unique values for Adenopathy:
# ['No Lympth Adenopathy' 'Right Side Body Adenopathy'
#  'Extensive and Widespread' 'Left Side Body Adenopathy' 'Bilateral'
#  'Posterior']
#
# Unique values for Cancer Metastasis:
# ['no evidence of distant metastasis' 'the presence of distant metastasis']
#
# Unique values for Stage:
# ['First-Stage' 'Second-Stage' 'IVB' 'Third-Stage' 'IVA']
#
# Unique values for Types of Thyroid Cancer:
# ['Micropapillary' 'Papillary' 'Follicular' 'Hurthel cell']

# %%
# prompt: pie chart for ( adenopathy, cancer metastasis, stage and types of thyroid cancer") these column , change header name that is most indication for each chart

import matplotlib.pyplot as plt
# Pie chart for Adenopathy
labels = data['Adenopathy'].value_counts().index.to_list()
sizes = data['Adenopathy'].value_counts().to_list()
fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
ax.set_title('Adenopathy Distribution')
plt.show()

# Pie chart for Cancer Metastasis
labels = data['Cancer Metastasis'].value_counts().index.to_list()
sizes = data['Cancer Metastasis'].value_counts().to_list()
fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
ax.set_title('Cancer Metastasis Distribution')
plt.show()

# Pie chart for Stage
labels = data['Stage'].value_counts().index.to_list()
sizes = data['Stage'].value_counts().to_list()
fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
ax.set_title('Stage Distribution')
plt.show()

# Pie chart for Types of Thyroid Cancer
labels = data['Types of Thyroid Cancer (Pathology)'].value_counts().index.to_list()
sizes = data['Types of Thyroid Cancer (Pathology)'].value_counts().to_list()
fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
ax.set_title('Types of Thyroid Cancer Distribution')
plt.show()

# %%
# prompt: Visualize the distribution of above colum using a histogram  and plot subplot as (2,2)

import matplotlib.pyplot as plt
import seaborn as sns

# Create a 2x2 grid of subplots
fig, axes = plt.subplots(2, 2, figsize=(20,15))

# Histogram for Adenopathy
sns.histplot(data=data, x="Adenopathy", palette="OrRd", ax=axes[0, 0])
axes[0, 0].set_title('Adenopathy Distribution')
axes[0, 0].set_xlabel('Adenopathy')
axes[0, 0].set_ylabel('Count')
plt.setp(axes[0, 0].get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

# Histogram for Cancer Metastasis
sns.histplot(data=data, x="Cancer Metastasis", palette="OrRd", ax=axes[0, 1])
axes[0, 1].set_title('Cancer Metastasis Distribution')
axes[0, 1].set_xlabel('Cancer Metastasis')
axes[0, 1].set_ylabel('Count')

# Histogram for Stage
sns.histplot(data=data, x="Stage", palette="OrRd", ax=axes[1, 0])
axes[1, 0].set_title('Stage Distribution')
axes[1, 0].set_xlabel('Stage')
axes[1, 0].set_ylabel('Count')
plt.xticks(rotation=70)

# Histogram for Types of Thyroid Cancer
sns.histplot(data=data, x="Types of Thyroid Cancer (Pathology)", palette="OrRd", ax=axes[1, 1])
axes[1, 1].set_title('Types of Thyroid Cancer Distribution')
axes[1, 1].set_xlabel('Types of Thyroid Cancer')
axes[1, 1].set_ylabel('Count')

# Rotate x-axis labels for Types of Thyroid Cancer
plt.setp(axes[1, 1].get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

# Show the plot
plt.show()

# %%
# prompt: the distribution of ages based on the presence and location of adenopathy using a swarm plot.

import matplotlib.pyplot as plt
import seaborn as sns

# Create a swarm plot to visualize the distribution of ages based on the presence and location of adenopathy
sns.swarmplot(x="Adenopathy", y="Age", data=data, palette="OrRd")

# Add a title and labels
plt.title("Distribution of Ages by Adenopathy")
plt.xlabel("Adenopathy")
plt.ylabel("Age")
plt.xticks(rotation=70)
plt.legend(title='Adenopathy', bbox_to_anchor=(.05, 1), loc='upper left')
plt.show()

# Show the plot
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# prompt: handling the missing values

# 1. Check for missing values in each column
missing_values = data.isnull().sum()

# 2. Drop columns with a significant number of missing values
threshold = 0.5  # Drop columns with more than 50% missing values
data = data.dropna(axis=1, thresh=int(threshold * len(data)))

# 3. Impute missing values in remaining columns
# Choose an appropriate imputation strategy based on the data type and distribution

# For numerical columns, you can use the mean, median, or mode
numerical_columns = data.select_dtypes(include=['int64', 'float64']).columns
data[numerical_columns] = data[numerical_columns].fillna(data[numerical_columns].mean())

# For categorical columns, you can use the mode or a constant value
categorical_columns = data.select_dtypes(include=['object']).columns
data[categorical_columns] = data[categorical_columns].fillna(data[categorical_columns].mode().iloc[0])

# 4. Verify that there are no missing values remaining
missing_values = data.isnull().sum()
print(missing_values)
# Out:
# Age                                    0
# Gender                                 0
# Smoking                                0
# Smoking History                        0
# Radiotherapy History                   0
# Thyroid Function                       0
# Physical Examination                   0
# Adenopathy                             0
# Types of Thyroid Cancer (Pathology)    0
# Focality                               0
# Risk                                   0
# Tumor                                  0
# Lymph Nodes                            0
# Cancer Metastasis                      0
# Stage                                  0
# Treatment Response                     0
# Recurred                               0
# Risk Rate (Out of 3)                   0
# dtype: int64

# %%
# prompt: encoading and scaling

# Encode categorical variables
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

for col in data.select_dtypes(include=['object']):
    data[col] = le.fit_transform(data[col])

# Scale numerical variables
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

data[numerical_columns] = scaler.fit_transform(data[numerical_columns])

# Show the transformed data
data.head()
# Out:
#         Age  Gender  Smoking  Smoking History  Radiotherapy History  \
# 0 -0.917439       0        0                0                     0
# 1 -0.454315       0        0                1                     0
# 2 -0.718957       0        0                0                     0
# 3  1.398184       0        0                0                     0
# 4  1.398184       0        0                0                     0
#
#    Thyroid Function  Physical Examination  Adenopathy  \
# 0                 2                     3           3
# 1                 2                     1           3
# 2                 2                     4           3
# 3                 2                     4           3
# 4                 2                     1           3
#
#    Types of Thyroid Cancer (Pathology)  Focality  Risk  Tumor  Lymph Nodes  \
# 0                                    2         1     2      5            0
# 1                                    2         1     2      5            0
# ...

# %%
# prompt: Using dataframe data: create a random forest model

from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model.fit(data.drop('Risk Rate (Out of 3)', axis=1), data['Risk Rate (Out of 3)'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-3578800dd608> in <cell line: 6>()
#       4
#       5 model = RandomForestClassifier()
# ----> 6 model.fit(data.drop('Risk Rate (Out of 3)', axis=1), data['Risk Rate (Out of 3)'])
#
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     383         self.n_outputs_ = y.shape[1]
#     384
# --> 385         y, expanded_class_weight = self._validate_y_class_weight(y)
#     386
#     387         if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py in _validate_y_class_weight(self, y)
#     744
#     745     def _validate_y_class_weight(self, y):
# --> 746         check_classification_targets(y)
#     747
#     748         y = np.copy(y)
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# Assuming the problem is a classification problem
X = data.drop('target', axis=1)
y = data['target']

model = RandomForestClassifier()
model.fit(X, y)

# Feature importance
importances = model.feature_importances_
indices = np.argsort(importances)[::-1]

for f in range(X.shape[1]):
    print(f"{X.columns[indices[f]]}: {importances[indices[f]]}")
# Out:
#   File "<ipython-input-78-f9c9989cbf6e>", line 1
#     create a random forest model
#            ^
# SyntaxError: invalid syntax
